# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitaparasher04/numpy_panda_matlab_DataScience/blob/main/matplotFile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title("A Simple Sine Wave")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()


gas = pd.read_csv("gas_prices.csv")
gas
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-4137046854.py in <cell line: 0>()
#      12
#      13
# ---> 14 gas = pd.read_csv("gas_prices.csv")
#      15 gas
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %% [markdown]
# # import and read the csv file *gas_prices*.csv

# %%
#  np.read_csv("gas_prices.csv")
# df = pd.read_csv("gas_prices.csv")
# print(df)
# \read file


# create a simple graph
# plt.plot(gas.Year,gas.USA)
# plt.show()


# apply simple functions
# plt.plot(gas.Year,gas.USA)
# plt.plot(gas.Year,gas.Canada)
# plt.plot(gas.Year,gas["South Korea"])
# plt.show()
# plt.plot(gas.Year, gas.USA, 'r-', marker='o')
# plt.plot(gas.Year,gas.Canada)
# plt.plot(gas.Year,gas["South Korea"])

# legend function uses label in the plot() function
# plt.plot(gas.Year, gas.USA, 'r-', marker='o',label='USA')
# plt.plot(gas.Year,gas.Canada,'b-',marker='o',label='Canada')
# plt.plot(gas.Year,gas["South Korea"],'g-',marker='o',label='South Korea')

# plt.title('Gas Prices over time')
# plt.xticks(gas.Year)
# plt.xlabel('years')
# plt.ylabel('price')
# plt.legend()

# xticks() or yticks() have different ways
# plt.plot(gas.Year, gas.USA, 'r-', marker='o',label='USA')
# plt.plot(gas.Year,gas.Canada,'b-',marker='o',label='Canada')
# plt.plot(gas.Year,gas["South Korea"],'g-',marker='o',label='South Korea')

# plt.title('Gas Prices over time')
# # ####plt.xticks(gas.Year)
# plt.xticks(gas.Year[::10])
# plt.xlabel('years')
# plt.ylabel('price')
# plt.legend()


# figure(figsize=(x,y)) function implimentation
# plt.figure(figsize=(8,5))

# plt.plot(gas.Year, gas.USA, 'r-', marker='o',label='USA')
# plt.plot(gas.Year,gas.Canada,'b-',marker='o',label='Canada')
# plt.plot(gas.Year,gas["South Korea"],'g-',marker='o',label='South Korea')


# plt.title('Gas Prices over time')
# # ####plt.xticks(gas.Year)
# plt.xticks(gas.Year[::3])
# # plt.yticks(gas.USA)
# plt.xlabel('years')
# plt.ylabel('price')
# plt.xlim([1990,2009])

# plt.legend()

plt.show()

# %% [markdown]
# # New Section

# %%
# !git status
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %% [markdown]
# hi

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git add .

# %%
# !git commit -m "rename file"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@9a2b02ae87dc.(none)')

# %%
# !git config --global user.email "ankitaparasher04@users.noreply.github.com"

# %%
# !git commit -m "rename file"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !mv /content/numpy_panda_matlab_DataScience/
# Out:
# mv: missing destination file operand after '/content/numpy_panda_matlab_DataScience/'
# Try 'mv --help' for more information.

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !ls /content/numpy_panda_matlab_DataScience
# Out:
# gas_prices.csv	README.md  Untitled0.ipynb

# %%
# %cd /content/numpy_panda_matlab_DataScience
# Out:
# /content/numpy_panda_matlab_DataScience
